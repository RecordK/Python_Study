# %% [markdown]
# # 피자집 주문데이터를 분석하세요

# %%
url_area = "https://raw.githubusercontent.com/KimYounghwan/bigdata/master/m_area.csv"
url_store = "https://raw.githubusercontent.com/KimYounghwan/bigdata/master/m_store.csv"
url_order_202104 = "https://raw.githubusercontent.com/KimYounghwan/bigdata/master/tbl_order_202104.csv"
url_order_202105 = "https://raw.githubusercontent.com/KimYounghwan/bigdata/master/tbl_order_202105.csv"
url_order_202106 = "https://raw.githubusercontent.com/KimYounghwan/bigdata/master/tbl_order_202106.csv"

# %% [markdown]
# # 한글적용

# %%
# 코랩 한글 적용
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# 코랩 한글 적용 후 런타임 재시작
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
plt.rc('axes', unicode_minus=False)
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following packages were automatically installed and are no longer required:
#   cuda-command-line-tools-10-0 cuda-command-line-tools-10-1
#   cuda-command-line-tools-11-0 cuda-compiler-10-0 cuda-compiler-10-1
#   cuda-compiler-11-0 cuda-cuobjdump-10-0 cuda-cuobjdump-10-1
#   cuda-cuobjdump-11-0 cuda-cupti-10-0 cuda-cupti-10-1 cuda-cupti-11-0
#   cuda-cupti-dev-11-0 cuda-documentation-10-0 cuda-documentation-10-1
#   cuda-documentation-11-0 cuda-documentation-11-1 cuda-gdb-10-0 cuda-gdb-10-1
#   cuda-gdb-11-0 cuda-gpu-library-advisor-10-0 cuda-gpu-library-advisor-10-1
#   cuda-libraries-10-0 cuda-libraries-10-1 cuda-libraries-11-0
#   cuda-memcheck-10-0 cuda-memcheck-10-1 cuda-memcheck-11-0 cuda-nsight-10-0
#   cuda-nsight-10-1 cuda-nsight-11-0 cuda-nsight-11-1 cuda-nsight-compute-10-0
# ...

# %% [markdown]
# # 본 테스트

# %%
import pandas as pd

# %%
# url_area를 읽어 area에 저장, 출력하세요
area=pd.read_csv(url_area)
area
# Out:
#   area_cd wide_area narrow_area
# 0      SL        서울          서울
# 1      BS        부산          부산
# 2      DJ        대전          대전
# 3      GJ        광주          광주
# 4      SJ        세종          세종
# 5      GN        경기        경기남부
# 6      GB        경기        경기북부

# %%
# area 길이를 출력하세요
len(area)
# Out:
# 7

# %%
# url_store를 읽어 store에 저장, 출력하세요
store=pd.read_csv(url_store)
store
# Out:
#      store_id store_name area_cd
# 0           1      삼일대로점      SL
# 1           2      세종대로점      SL
# 2           3       무교로점      SL
# 3           4      덕수궁길점      SL
# 4           5      서소문로점      SL
# ..        ...        ...     ...
# 192       193       방죽로점      GB
# 193       194      일산동구점      GB
# 194       195       화중로점      GB
# 195       196       석봉로점      GB
# 196       999       보수담당      SL
#
# [197 rows x 3 columns]

# %%
# store의 길이를 출력하세요
len(store)
# Out:
# 197

# %%
# url_order_202104를 읽어 order_202104에 저장, 출력하세요
'''
order_id 주문id
store_id 매장id
customer_id 고객id
coupon_cd 쿠폰
sales_detail_id 상세주문id
order_accept_date 주문일시
delivered_date 배달완료일시
takeout_flag 주문형태  1이면 "takeout" , 0이면 "delivery"
total_amount 총주문액(매출)
status 주문최종상태 0: '주문 접수' 1:'지불 완료' 2:'배달 완료' 9:'주문 취소'
'''
order_202104=pd.read_csv(url_order_202104)
order_202104
# Out:
#         order_id  store_id customer_id  ...  takeout_flag  total_amount status
# 0       34104383        11   C65806632  ...             1         28270      1
# 1       70652318        59   C09760173  ...             0         28270      2
# 2       71640388       195   C61227084  ...             0         26470      9
# 3       75673365       127   C64119972  ...             0         23080      2
# 4        9077529       174   C10231192  ...             0         46920      2
# ...          ...       ...         ...  ...           ...           ...    ...
# 233257  61665702       103   C51797758  ...             0         35300      2
# 233258  31151690       119   C04883863  ...             0         32340      2
# 233259  15955692       175   C87594637  ...             0         36170      9
# 233260  73251339       145   C93839111  ...             0         36170      2
# 233261  42442108       117   C44570215  ...             1         18990      1
#
# ...

# %%
# order_202104의 행 길이를 출력하세요
len(order_202104)
# Out:
# 233262

# %%
# url_order_202105를 읽어 order_202105에 저장, 출력하세요
order_202105=pd.read_csv(url_order_202105)
order_202105
# Out:
#         order_id  store_id customer_id  ...  takeout_flag  total_amount status
# 0       84536666        16   C09876770  ...             0         32340      2
# 1       88276008       158   C68585017  ...             0         38650      2
# 2       30853149        97   C47161470  ...             0         28270      2
# 3        2266595        95   C61461123  ...             0         23160      2
# 4        7086301        49   C01007474  ...             0         19000      9
# ...          ...       ...         ...  ...           ...           ...    ...
# 241137  80834230       110   C44748299  ...             0         35020      2
# 241138  65940233       164   C68733497  ...             0         21120      2
# 241139  49922027        23   C66722860  ...             0         26470      2
# 241140  80642623        35   C32096353  ...             0         28270      2
# 241141  13890502       182   C40646464  ...             0         26770      2
#
# ...

# %%
# order_202105의 행 길이를 출력하세요
len(order_202105)
# Out:
# 241142

# %%
# url_order_202106를 읽어 order_202106에 저장, 출력하세요
order_202106=pd.read_csv(url_order_202106)
order_202106
# Out:
#         order_id  store_id customer_id  ...  takeout_flag  total_amount status
# 0       42067158        48   C87044944  ...             0         26030      9
# 1       15752986       164   C16364398  ...             0         28080      2
# 2       94347153        23   C53806156  ...             0         46920      2
# 3       89104104        89   C52845352  ...             0         28270      2
# 4       14849014        78   C40273707  ...             0         30500      2
# ...          ...       ...         ...  ...           ...           ...    ...
# 233297  17154702       157   C83348111  ...             0         44620      2
# 233298  49731888       185   C55784926  ...             1         23280      1
# 233299  93805252        79   C87712110  ...             0         26150      2
# 233300  33290611       116   C83096347  ...             1         35020      1
# 233301  84666999        97   C55599659  ...             0         23120      2
#
# ...

# %%
# order_202106의 행 길이를 출력하세요
len(order_202106)
# Out:
# 233302

# %%
# order_202104, order_202105, order_202106를 수직결합하여 order_all에 저장, 출력하세요
order_all=order_202104.append(order_202105)
order_all=order_all.append(order_202106)
order_all
# Out:
#         order_id  store_id customer_id  ...  takeout_flag  total_amount status
# 0       34104383        11   C65806632  ...             1         28270      1
# 1       70652318        59   C09760173  ...             0         28270      2
# 2       71640388       195   C61227084  ...             0         26470      9
# 3       75673365       127   C64119972  ...             0         23080      2
# 4        9077529       174   C10231192  ...             0         46920      2
# ...          ...       ...         ...  ...           ...           ...    ...
# 233297  17154702       157   C83348111  ...             0         44620      2
# 233298  49731888       185   C55784926  ...             1         23280      1
# 233299  93805252        79   C87712110  ...             0         26150      2
# 233300  33290611       116   C83096347  ...             1         35020      1
# 233301  84666999        97   C55599659  ...             0         23120      2
#
# ...

# %%
# order_all의 행 길이를 출력하세요
len(order_all)
# Out:
# 707706

# %%
# 칼럼별 결측치 갯수를 출력하세요
order_all.isna().sum()
# Out:
# order_id             0
# store_id             0
# customer_id          0
# coupon_cd            0
# sales_detail_id      0
# order_accept_date    0
# delivered_date       0
# takeout_flag         0
# total_amount         0
# status               0
# dtype: int64

# %%
# order_all의 구조를 출력하세요
order_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 707706 entries, 0 to 233301
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   order_id           707706 non-null  int64
#  1   store_id           707706 non-null  int64
#  2   customer_id        707706 non-null  object
#  3   coupon_cd          707706 non-null  int64
#  4   sales_detail_id    707706 non-null  int64
#  5   order_accept_date  707706 non-null  object
#  6   delivered_date     707706 non-null  object
#  7   takeout_flag       707706 non-null  int64
#  8   total_amount       707706 non-null  int64
#  9   status             707706 non-null  int64
# dtypes: int64(7), object(3)
# memory usage: 59.4+ MB

# %%
# order_all의 수치형 칼럼의 기본 통계량을 출력하세요
order_all.describe()
# Out:
#            order_id       store_id  ...   total_amount         status
# count  7.077060e+05  707706.000000  ...  707706.000000  707706.000000
# mean   5.000947e+07     103.935165  ...   29606.465156       3.083026
# std    2.889479e+07      86.373854  ...    9543.733832       2.836336
# min    2.200000e+01       1.000000  ...    6980.000000       1.000000
# 25%    2.501320e+07      51.000000  ...   23080.000000       2.000000
# 50%    4.999599e+07      99.000000  ...   28080.000000       2.000000
# 75%    7.508354e+07     148.000000  ...   36170.000000       2.000000
# max    9.999972e+07     999.000000  ...   51000.000000       9.000000
#
# [8 rows x 7 columns]

# %%
# order_all의 문자열 칼럼의 기본 통계량을 출력하세요
order_all[order_all.columns[order_all.dtypes=='O']].describe()
# Out:
#        customer_id order_accept_date    delivered_date
# count       707706            707706            707706
# unique       41602             59058             64043
# top      C64592879  2021-04-29 13:11  2021-06-30 18:08
# freq           112                32                29

# %%
store
# Out:
#      store_id store_name area_cd
# 0           1      삼일대로점      SL
# 1           2      세종대로점      SL
# 2           3       무교로점      SL
# 3           4      덕수궁길점      SL
# 4           5      서소문로점      SL
# ..        ...        ...     ...
# 192       193       방죽로점      GB
# 193       194      일산동구점      GB
# 194       195       화중로점      GB
# 195       196       석봉로점      GB
# 196       999       보수담당      SL
#
# [197 rows x 3 columns]

# %%
# order_all와 store_id는 매장id이고 매장id에 대한 매장이름은 store의 store_name에 저장되어있다.
# order_all와 store를 수평연결하여 order_all에 저장하세요
order_all=order_all.merge(store, on='store_id')
order_all
# Out:
#         order_id  store_id customer_id  ...  status  store_name area_cd
# 0       34104383        11   C65806632  ...       1        자양로점      SL
# 1       50371413        11   C30648071  ...       1        자양로점      SL
# 2       56316692        11   C51330474  ...       9        자양로점      SL
# 3       71835412        11   C20466856  ...       2        자양로점      SL
# 4       41702196        11   C83414520  ...       9        자양로점      SL
# ...          ...       ...         ...  ...     ...         ...     ...
# 707701  11256275        64   C73900149  ...       2      시흥대로2점      SL
# 707702   1460085        64   C31790706  ...       2      시흥대로2점      SL
# 707703  97374412        64   C39230910  ...       2      시흥대로2점      SL
# 707704  14952324        64   C58448884  ...       9      시흥대로2점      SL
# 707705   1528255        64   C87003007  ...       2      시흥대로2점      SL
#
# [707706 rows x 12 columns]

# %%
# order_all와 area를 수평연결하여 order_all에 저장하세요
order_all=order_all.merge(area)
order_all
# Out:
#         order_id  store_id customer_id  ...  area_cd  wide_area narrow_area
# 0       34104383        11   C65806632  ...       SL         서울          서울
# 1       50371413        11   C30648071  ...       SL         서울          서울
# 2       56316692        11   C51330474  ...       SL         서울          서울
# 3       71835412        11   C20466856  ...       SL         서울          서울
# 4       41702196        11   C83414520  ...       SL         서울          서울
# ...          ...       ...         ...  ...      ...        ...         ...
# 707701  49658304       185   C28441229  ...       SJ         세종          세종
# 707702  55120366       185   C07948209  ...       SJ         세종          세종
# 707703  10901734       185   C12078756  ...       SJ         세종          세종
# 707704  64981686       185   C12078756  ...       SJ         세종          세종
# 707705  49731888       185   C55784926  ...       SJ         세종          세종
#
# [707706 rows x 14 columns]

# %%
order_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 707706 entries, 0 to 707705
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   order_id           707706 non-null  int64
#  1   store_id           707706 non-null  int64
#  2   customer_id        707706 non-null  object
#  3   coupon_cd          707706 non-null  int64
#  4   sales_detail_id    707706 non-null  int64
#  5   order_accept_date  707706 non-null  object
#  6   delivered_date     707706 non-null  object
#  7   takeout_flag       707706 non-null  int64
#  8   total_amount       707706 non-null  int64
#  9   status             707706 non-null  int64
#  10  store_name         707706 non-null  object
#  11  area_cd            707706 non-null  object
#  12  wide_area          707706 non-null  object
#  13  narrow_area        707706 non-null  object
# dtypes: int64(7), object(7)
# memory usage: 81.0+ MB

# %%
# takeout_name 칼럼 추가한다. 
# takeout_flag = 1이면 takeout_name에 "takeout",
# takeout_flag = 0이면 takeout_name에 "delivery"를 저장한다.
a=[]
for i in order_all['takeout_flag']:
   a.append('takeout') if i==1 else a.append('delivery')
order_all['takeout_name']=a
order_all
# Out:
#         order_id  store_id customer_id  ...  wide_area  narrow_area takeout_name
# 0       34104383        11   C65806632  ...         서울           서울      takeout
# 1       50371413        11   C30648071  ...         서울           서울      takeout
# 2       56316692        11   C51330474  ...         서울           서울     delivery
# 3       71835412        11   C20466856  ...         서울           서울     delivery
# 4       41702196        11   C83414520  ...         서울           서울      takeout
# ...          ...       ...         ...  ...        ...          ...          ...
# 707701  49658304       185   C28441229  ...         세종           세종     delivery
# 707702  55120366       185   C07948209  ...         세종           세종     delivery
# 707703  10901734       185   C12078756  ...         세종           세종      takeout
# 707704  64981686       185   C12078756  ...         세종           세종      takeout
# 707705  49731888       185   C55784926  ...         세종           세종      takeout
#
# ...

# %%
# status가 0이면 status_name에 '주문 접수', 
# status가 1이면 status_name에 '지불 완료', 
# status가 2이면 status_name에 '배달 완료', 
# status가 9이면 status_name에 '주문 취소'저장한다
b=[]
for i in order_all['status']:
  if i==0:b.append('주문 접수') 
  elif i==1: b.append('지불 완료')
  elif i==2: b.append('배달 완료')
  elif i==9: b.append('주문 취소')
order_all['status_name']=b
order_all
# Out:
#         order_id  store_id customer_id  ...  narrow_area  takeout_name status_name
# 0       34104383        11   C65806632  ...           서울       takeout       지불 완료
# 1       50371413        11   C30648071  ...           서울       takeout       지불 완료
# 2       56316692        11   C51330474  ...           서울      delivery       주문 취소
# 3       71835412        11   C20466856  ...           서울      delivery       배달 완료
# 4       41702196        11   C83414520  ...           서울       takeout       주문 취소
# ...          ...       ...         ...  ...          ...           ...         ...
# 707701  49658304       185   C28441229  ...           세종      delivery       주문 취소
# 707702  55120366       185   C07948209  ...           세종      delivery       배달 완료
# 707703  10901734       185   C12078756  ...           세종       takeout       지불 완료
# 707704  64981686       185   C12078756  ...           세종       takeout       지불 완료
# ...

# %%
# order_all을 "order_all.csv"에 저장하세요
order_all.to_csv('order_all.csv')

# %%
# delivered_date 칼럼을 datetime 타입으로 변환하여 delivered_date 칼럼에 저장한다.
order_all['delivered_date']=pd.to_datetime(order_all['delivered_date'])
# delivered_date칼럼에서 년월(YYYYMM)을 추출하여 delivered_month칼럼에 저장한다.
order_all['delivered_month'] = order_all['delivered_date'].apply(lambda x:x.strftime('%Y%m'))
# delivered_date 칼럼과 delivered_month 칼럼만 추출하여 앞부분 5줄만 출력한다
order_all[['delivered_date','delivered_month']].head()
# Out:
#        delivered_date delivered_month
# 0 2021-04-01 11:39:00          202104
# 1 2021-04-01 11:13:00          202104
# 2 2021-04-01 11:41:00          202104
# 3 2021-04-01 12:20:00          202104
# 4 2021-04-01 12:03:00          202104

# %%
# '주문 취소' 제외한 
# 월별(delivered_month) 매출(total_amount)의 갯수와 총합과 평균을 출력한다
order_all[order_all['status_name']!='주문 취소'].pivot_table(
    index='delivered_month',
    values='total_amount',
    aggfunc=['count','sum','mean']
)
# Out:
#                        count          sum          mean
#                 total_amount total_amount  total_amount
# delivered_month
# 202104                190398   5636128170  29601.824441
# 202105                196774   5826695540  29611.104821
# 202106                190357   5636586130  29610.606019

# %%
# 월별(delivered_month) 매출(total_amount)의 총합을 선그래프로 출력하시오

order_all[order_all['status_name']!='주문 취소'].pivot_table(
    index='delivered_month',
    values='total_amount',
    aggfunc='sum'
).plot()

# %%
# 월별(delivered_month) 매출(total_amount)의 평균의 선그래프로 출력하시오
order_all[order_all['status_name']!='주문 취소'].pivot_table(
    index='delivered_month',
    values='total_amount',
    aggfunc='mean'
).plot()

# %%
# 매출(total_amount)의 히스토그램을 출력하시오. 간격 갯수는 20개.
order_all['total_amount'].hist(bins=20)

# %%
# 월별(delivered_month) 지역(narrow_area) 별 매출()평균을 출력
q=order_all.pivot_table(
    index='delivered_month',
    columns='narrow_area',
    values='total_amount'
)
q
# Out:
# narrow_area              경기남부          경기북부  ...            서울            세종
# delivered_month                              ...
# 202104           29967.888107  29408.862941  ...  29628.514113  29402.832834
# 202105           29987.514751  29424.063675  ...  29634.170052  29453.040744
# 202106           29948.616923  29423.377254  ...  29633.078875  29419.356025
#
# [3 rows x 7 columns]

# %%
# 월별(delivered_month) 지역(narrow_area) 별 매출(total_amount)평균을 선그래프로 출력하시오
q.plot()

# %%
# 시간별 지역(narrow_area) 별 매출(total_amount)평균을 선그래프로 출력하시오
order_all['hour'] = order_all['delivered_date'].dt.hour
order_all.pivot_table(
    index='hour',
    columns='narrow_area',
    values='total_amount'
).plot()

# %%
# 매장(store_id)별 매출(total_amount)의 기본 통계(갯수,평균,중앙값,최대값, 최소값)를 출력하세요
order_all.pivot_table(
    index='store_id',
    values='total_amount',
    aggfunc=['count',	'mean',	'median',	'max',	'min']
)
# Out:
#                 count          mean       median          max          min
#          total_amount  total_amount total_amount total_amount total_amount
# store_id
# 1                3553  31218.156487        29870        51000        18570
# 2                3477  29130.954846        27320        47440         6980
# 3                2576  27253.695652        26770        47440         6980
# 4                3023  28995.418458        26770        47440         6980
# 5                3742  30225.192410        29870        51000         6980
# ...               ...           ...          ...          ...          ...
# 193              3668  31252.919847        30500        51000         9390
# 194              3379  28175.788695        27500        41440         9390
# 195              3480  28749.270115        26770        47440         6980
# 196              2488  29048.557074        27790        46590         6980
# ...

# %%
# 삼일대로점의 주단위 매출을 출력하세요( pandas.Series.dt.weekofyear: 연중 몇 째주 )
order_all['week']=order_all['delivered_date'].dt.weekofyear

v=order_all[order_all['store_name']=='삼일대로점'].pivot_table(
    index='week',
    values='total_amount',
    aggfunc='sum'
)
v
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#       total_amount
# week
# 13         4722890
# 14         8569280
# 15         8605220
# 16         8421720
# 17         8420160
# 18         8626920
# 19         8527660
# 20         8571290
# 21         8547160
# 22         8631240
# 23         8486770
# 24         8615800
# 25         8526000
# 26         3646000

# %%
# 주문취소 제외
v1=order_all[~order_all['status_name'].isin(['주문 취소'])][order_all['store_name']=='삼일대로점'].pivot_table(
    index='week',
    values='total_amount',
    aggfunc='sum'
)
v1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#       total_amount
# week
# 13         3857700
# 14         6980230
# 15         6723530
# 16         6998760
# 17         6941540
# 18         7367750
# 19         7158910
# 20         6820650
# 21         6879070
# 22         6719920
# 23         6948180
# 24         6883070
# 25         6821680
# 26         3000060

# %%
# 삼일대로점의 주단위 매출을 선그래프로 출력하세요
#주문취소포함
v.plot()

# %%
#주문취소제외
v1.plot()

# %%
# 삼일대로점의 주단위 매출과 가장 비슷한 매출 패턴을 가진 매장과 

# 주문취소매출포함
def store(i):
  l=order_all[order_all['store_name']==i].pivot_table(
    index='week',
    values='total_amount',
    aggfunc='sum'
  )
  return l
# 주문취소매출제외
def store1(i):
  l=order_all[~order_all['status_name'].isin(['주문 취소'])][order_all['store_name']==i].pivot_table(
    index='week',
    values='total_amount',
    aggfunc='sum'
  )
  return l
삼일대로점=v['total_amount']
mindiffsum = 999999999999999
diffsumsn = 'ㅋ'

# %%
# 모든 스토어이름
for i in order_all['store_name'].unique():
  if i =='삼일대로점':
    continue
  #idx번째 행 추출

  diffsum = ((삼일대로점 - store(i)['total_amount'])**2).values.sum() 
  if diffsum < mindiffsum:
    mindiffsum = diffsum
    diffsumsn = i

print("mindiffsum",mindiffsum)
print("비슷매장",diffsumsn)

# 모든 스토어이름
# 주문취소매출제외
삼일대로점1=v1['total_amount']
mindiffsum1 = 999999999999999
diffsumsn1 = 'ㅋ'
for i in order_all['store_name'].unique():
  if i =='삼일대로점':
    continue
  #idx번째 행 추출

  diffsum1 = ((삼일대로점1 - store1(i)['total_amount'])**2).values.sum() 
  if diffsum1 < mindiffsum1:
    mindiffsum1 = diffsum1
    diffsumsn1 = i

print("주문취소매출제외 mindiffsum",mindiffsum1)
print("주문취소매출제외 비슷매장",diffsumsn1)
# Out:
# mindiffsum 77081986500
# 비슷매장 신일서로점
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   del sys.path[0]
# 주문취소매출제외 mindiffsum 314703478000
# 주문취소매출제외 비슷매장 민락수변로점

# %%
a=v
a=a.merge(store(diffsumsn),on='week',how='outer',suffixes=(' 삼일대로점', diffsumsn))
a
a.plot()

# %%
#주문취소 매출제외
a=v1
a=a.merge(store1(diffsumsn1),on='week',how='outer',suffixes=(' 삼일대로점', diffsumsn1))
a
a.plot()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   del sys.path[0]

# %%
# 다른 매출 패턴을 가진 점을 추출하여 선그래프로 출력하세요
order_all['diffsum']=0
for i in order_all['store_name'].unique():
  diffsum = ((삼일대로점 - store(i)['total_amount'])**2).values.sum()
  order_all['store_name'].isin([i])
  order_all.loc[order_all['store_name'] == i, 'diffsum'] = diffsum

# %%
# 주문 취소 매출제외
order_all['diffsum1']=0
for i in order_all['store_name'].unique():
  diffsum1 = ((삼일대로점1 - store1(i)['total_amount'])**2).values.sum()
  order_all['store_name'].isin([i])
  order_all.loc[order_all['store_name'] == i, 'diffsum1'] = diffsum1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   del sys.path[0]

# %%
order_all.sort_values(by="diffsum",ascending=False)
# Out:
#         order_id  store_id customer_id  ...  week          diffsum         diffsum1
# 492557  68892536       105   C55011666  ...    21  600238307332000  395638970883000
# 491205  60963515       105   C95749834  ...    15  600238307332000  395638970883000
# 491218  60076681       105   C34788828  ...    15  600238307332000  395638970883000
# 491217  83287812       105   C28896442  ...    15  600238307332000  395638970883000
# 491216  81591050       105   C44315285  ...    15  600238307332000  395638970883000
# ...          ...       ...         ...  ...   ...              ...              ...
# 85734   66306568         1   C11256907  ...    21                0                0
# 85733   29918360         1   C80060946  ...    21                0                0
# 85732   33607722         1   C00244531  ...    21                0                0
# 85731   38916259         1   C18564906  ...    21                0                0
# ...

# %%
#주문취소 제외
order_all[~order_all['status_name'].isin(['주문 취소'])].sort_values(by="diffsum1",ascending=False)
# Out:
#         order_id  store_id customer_id  ...  week          diffsum         diffsum1
# 490715  39202051       105   C51893783  ...    13  600238307332000  395638970883000
# 297975    982106        39   C78611339  ...    14  600238307332000  395638970883000
# 297991  13163909        39   C11580534  ...    14  600238307332000  395638970883000
# 297990  25946078        39   C93732867  ...    14  600238307332000  395638970883000
# 297989  24435743        39   C54633860  ...    14  600238307332000  395638970883000
# ...          ...       ...         ...  ...   ...              ...              ...
# 85161   35313741         1   C33623566  ...    18                0                0
# 85160   71936769         1   C47153418  ...    18                0                0
# 85159   51162518         1   C86109634  ...    18                0                0
# 85157    5087031         1   C68879709  ...    18                0                0
# ...

# %%
for i in order_all.sort_values(by="diffsum",ascending=False).head(1)['store_name']:
  a=v
  a=a.merge(store(i),on='week',how='outer',suffixes=(' 삼일대로점', i))
  a
  a.plot()

# %%
#주문취소 매출 제외
for i in order_all.sort_values(by="diffsum1",ascending=False).head(1)['store_name']:
  a=v
  a=a.merge(store1(i),on='week',how='outer',suffixes=(' 삼일대로점', i))
  a
  a.plot()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   del sys.path[0]

# %%
order_all
# Out:
#         order_id  store_id customer_id  ...  hour  week        diffsum
# 0       34104383        11   C65806632  ...    11    13  2645949116000
# 1       50371413        11   C30648071  ...    11    13  2645949116000
# 2       56316692        11   C51330474  ...    11    13  2645949116000
# 3       71835412        11   C20466856  ...    12    13  2645949116000
# 4       41702196        11   C83414520  ...    12    13  2645949116000
# ...          ...       ...         ...  ...   ...   ...            ...
# 707701  49658304       185   C28441229  ...    21    26  6013263421000
# 707702  55120366       185   C07948209  ...    22    26  6013263421000
# 707703  10901734       185   C12078756  ...    22    26  6013263421000
# 707704  64981686       185   C12078756  ...    22    26  6013263421000
# 707705  49731888       185   C55784926  ...    22    26  6013263421000
#
# [707706 rows x 20 columns]

# %% [markdown]
# ## 해당항목들은 주문건수별 평균이 가장 높은 매장(주문취소포함)

# %%
# #주문건수별 평균 매출이 가장 높은 매장과 가장 낮은 매장과 매출평균을 추출하여 주단위 매출액을 선그래프로 그리시오

lll=[]
lll.append(order_all.pivot_table(
  index='store_name',
  values='total_amount',
  aggfunc='mean'
).sort_values('total_amount',ascending=False).head(1).index[0])
lll.append(order_all.pivot_table(
  index='store_name',
  values='total_amount',
  aggfunc='mean'
).sort_values('total_amount',ascending=False).tail(1).index[0])
#주문건수별 매출평균
avg=order_all['total_amount'].mean()
# 주단위위 주문건수별 매출평균
weekavgli=[]
for i in range(13,27):
  weekavgli.append(order_all.pivot_table(
    index='store_name',
    columns='week',
    values='total_amount',
    aggfunc='mean'
  )[i].mean())
weekavgli
week=[i for i in range(13,27)]
weekavgval=pd.DataFrame(weekavgli)
weekavgval.index=week
weekavgval
# Out:
#                0
# 13  29591.564356
# 14  29592.031486
# 15  29602.153069
# 16  29598.697011
# 17  29602.560951
# 18  29599.220817
# 19  29602.018251
# 20  29603.074230
# 21  29605.631833
# 22  29599.710849
# 23  29599.470269
# 24  29611.554097
# 25  29601.669085
# 26  29593.053243

# %%
plt.figure()
plt.axhline(y=avg, color='r', linewidth=1,label='주문건수매출평균',linestyle=':')
for i in lll:
  plt.plot(
      store(i)['total_amount'],
      label=i
  )

plt.plot(
      weekavgval,
      label='주단위 주문건수별매출평균 '
)

plt.xticks(rotation=45)
plt.legend()
plt.show()
print(avg,weekavgval)
# Out:
# 29606.465156435017                0
# 13  29591.564356
# 14  29592.031486
# 15  29602.153069
# 16  29598.697011
# 17  29602.560951
# 18  29599.220817
# 19  29602.018251
# 20  29603.074230
# 21  29605.631833
# 22  29599.710849
# 23  29599.470269
# 24  29611.554097
# 25  29601.669085
# 26  29593.053243

# %% [markdown]
# ##매장별 전체 매출이 1등과 꼴찌를 찾아서 그들의 주단위 매출평균을 그리세요(주문취소포함)
# ##매장별 전체 매출이 1등과 꼴찌 매장을 찾아서 그들의 주단위 매출평균을 그리세요

# %%
# 전체 매출이 가장 높은 매장과 가장 낮은 매장과 매출평균을 추출하여 주단위 매출액을 선그래프로 그리시오

lll=[]
lll.append(order_all.pivot_table(
  index='store_name',
  values='total_amount',
  aggfunc='sum'
).sort_values('total_amount',ascending=False).head(1).index[0])
lll.append(order_all.pivot_table(
  index='store_name',
  values='total_amount',
  aggfunc='sum'
).sort_values('total_amount',ascending=False).tail(1).index[0])
# 주문건수별 (total_amount)매출평균
avg=order_all['total_amount'].mean()

# 매장별 총 매출 평균 (total_amount)매출평균
avg1=order_all.pivot_table(
  index='store_name',
  values='total_amount',
  aggfunc='sum'
).sort_values('total_amount',ascending=False)['total_amount'].mean()

# 주단위 총 매출평균
weekavgli=[]
for i in range(13,27):
  weekavgli.append(order_all.pivot_table(
    index='store_name',
    columns='week',
    values='total_amount',
    aggfunc='sum'
  )[i].mean())
weekavgli
week=[i for i in range(13,27)]
weekavgval=pd.DataFrame(weekavgli)
weekavgval.index=week
weekavgval
# Out:
#                0
# 13  4.747965e+06
# 14  8.309310e+06
# 15  8.302289e+06
# 16  8.295417e+06
# 17  8.311485e+06
# 18  8.319781e+06
# 19  8.303591e+06
# 20  8.300357e+06
# 21  7.128668e+06
# 22  7.119284e+06
# 23  8.296213e+06
# 24  8.317239e+06
# 25  8.315034e+06
# 26  3.559156e+06

# %%
plt.figure()
plt.axhline(y=avg, color='r', linewidth=1,label='주문건수매출평균',linestyle=':')
# plt.axhline(y=avg1, color='b', linewidth=1,label='매장별 총 매출 평균',linestyle=':')
for i in lll:
  plt.plot(
      store(i)['total_amount'],
      label=i
  )
plt.plot(
      weekavgval,
      label='주단위 총총 매출평균 '
)
plt.xticks(rotation=45)
plt.legend()
plt.show()
print(avg,avg1)
# Out:
# 29606.377924314576 105625789.38144329

# %%
plt.figure()
plt.axhline(y=avg, color='r', linewidth=1,label='주문건수매출평균',linestyle=':')
plt.axhline(y=avg1, color='b', linewidth=1,label='매장별 총 매출 평균',linestyle=':')
for i in lll:
  plt.plot(
      store(i)['total_amount'],
      label=i
  )
plt.plot(
      weekavgval,
      label='주단위 총총 매출평균 '
)
plt.xticks(rotation=45)
plt.legend()
plt.show()
print(avg,avg1)
# Out:
# 29606.377924314576 105625789.38144329

# %% [markdown]
# #날씨

# %% [markdown]
# ##날씨함수

# %%
def get_weather(year, month, debug=False):
  '''
    year와 month에 해당하는 날짜의 맑음, 비 정보를 DataFrame으로 반환한다
  '''
  import pandas as pd
  url=f"https://www.weather.go.kr/w/obs-climate/land/past-obs/obs-by-day.do?stn=108&yy={year}&mm={month}&obs=1"
  w = pd.read_html(url, encoding="utf-8")
  평균기온=[]
  최고기온=[]
  최저기온=[]
  평균운량=[]
  일강수량=[]
  w_info=[]
  for i in range(1, 10, 2): #날씨정보는 홀수번째 행에 저장중.
    day_weather = w[1].loc[i] #홀수번째행 추출
    for wt in day_weather : #홀수번째 행의 각 칼럼 추출
      if pd.isna(wt): # 칼럼에 값이 없으면 다음 칼럼으로
        continue
      w_info.append(wt) # 칼럼에 값이 있으면 w_info에 저장
      wt_sp = wt.split()
      평균기온.append(wt_sp[0].split(":")[1].split("℃")[0])
      최고기온.append(wt_sp[1].split(":")[1].split("℃")[0])
      최저기온.append(wt_sp[2].split(":")[1].split("℃")[0])
      평균운량.append(wt_sp[3].split(":")[1])
      일강수량.append(wt_sp[4].split(":")[1])
      일강수량 = [ "0" if rain.strip()=="" or rain.endswith("0.0mm") else rain.split("mm")[0] for rain in 일강수량 ]
  if debug: # 디버그 옵션이 True이면 중간 결과물 출력
    display(w_info)
    print("날씨정보 길이:",len(w_info))
    display("일강수량:",일강수량)
  w_info2=[] # 날씨만 담을 리스트
  for wi in w_info:
    # print(wi.split()[-1])
    if not wi.endswith("mm"): # 정보글자가 강수량인 mm로 안끝나면 맑음
      w_info2.append("맑음")
      continue
    if wi.split(":")[-1]=="0.0mm": # 정보글자가 0.0mm로 안끝나면 맑음
      w_info2.append("맑음")
      continue
    w_info2.append("비") # 강수량 정보가 있으면 비
  if debug:
    display(w_info2)
  date_info2 = [] # 날짜정보 저장용  yyyy-mm-dd
  for i in range(1, len(w_info2)+1):
    date_info2.append( f"{year}-{month:02d}-{i:02d}"   )
  if debug:
    display(date_info2)
  weather_info = pd.DataFrame(
      [date_info2,평균기온,최고기온,최저기온,평균운량,일강수량, w_info2], 
      index=["날짜","평균기온","최고기온","최저기온","평균운량","일강수량","날씨"],
      dtype=float).T
  weather_info["평균기온"]=weather_info["평균기온"].astype(float)
  weather_info["최고기온"]=weather_info["최고기온"].astype(float)
  weather_info["최저기온"]=weather_info["최저기온"].astype(float)
  weather_info["평균운량"]=weather_info["평균운량"].astype(float)
  weather_info["일강수량"]=weather_info["일강수량"].astype(float)
  return weather_info

# %% [markdown]
# ##문제

# %%
# https://www.weather.go.kr/w/obs-climate/land/past-obs/obs-by-day.do?stn=108&yy=2021&mm=4&obs=1
# 위주소는 2021년 4월달 날씨 정보를 제공하는 페이지이다.
# 위주소를 이용하여 날씨정보를 추출하여 비온날과 안온날의 전체 평균 매출액을 바그래프로 출력하세요.
# 사용예 2021년 4월 날씨 추출
wt4 = get_weather(2021,4) 
wt5 = get_weather(2021,5) 
wt6 = get_weather(2021,6) 
wt4
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: Could not cast to float64, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Could not cast to float64, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: FutureWarning: Could not cast to float64, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised
#   import sys
#             날짜  평균기온  최고기온  최저기온  평균운량  일강수량  날씨
# ...

# %%
wtall=wt4.append(wt5)
wtall=wtall.append(wt6)

# %%
wtall['날짜']=pd.to_datetime(wtall['날짜'])
wtall
# Out:
#            날짜  평균기온  최고기온  최저기온  평균운량  일강수량  날씨
# 0  2021-04-01  17.7  24.0  12.0   5.3   0.0  맑음
# 1  2021-04-02  17.8  23.0  12.5   8.1   0.0  맑음
# 2  2021-04-03  14.9  18.0  10.9   9.9  56.2   비
# 3  2021-04-04  11.9  15.8   9.0   6.3   0.6   비
# 4  2021-04-05  11.9  19.3   5.4   2.3   0.0  맑음
# ..        ...   ...   ...   ...   ...   ...  ..
# 25 2021-06-26  22.8  26.7  19.9   7.3   4.5   비
# 26 2021-06-27  24.5  30.8  19.8   5.4  38.2   비
# 27 2021-06-28  23.7  29.2  21.0   8.1   0.1   비
# 28 2021-06-29  23.9  28.4  21.3   6.5   8.0   비
# 29 2021-06-30  24.3  28.8  21.0   6.1   6.0   비
#
# [89 rows x 7 columns]

# %%
order_all['날짜']= order_all['delivered_date'].apply(lambda x:x.strftime('%Y-%m-%d'))
order_all['날짜']=pd.to_datetime(order_all['날짜'])

# %%
order_all=order_all.merge(wtall,on='날짜')

# %%
order_all['날씨'].isna().sum()
# Out:
# 0

# %% [markdown]
# # 위주소를 이용하여 날씨정보를 추출하여 비온날과 안온날의 전체 평균 매출액을 바그래프로 출력하세요.

# %% [markdown]
# ## 비온날과과 안온날의 주문건수별 평균매출액 (현재데이터는 주문건수별 데이터이므로)

# %%
# 비온날과과 안온날의 주문건수별 평균매출액
order_all.pivot_table(
    index='날씨',
    values='total_amount',
    aggfunc='mean'
)
# Out:
#     total_amount
# 날씨
# 맑음  29608.423732
# 비   29603.502040

# %%
order_all.pivot_table(
    index='날씨',
    values='total_amount',
    aggfunc='mean'
).plot.bar()

# %% [markdown]
# # 비온날과 안온날의 전체 매출액의 평균

# %%
# 위주소를 이용하여 날씨정보를 추출하여 비온날과 안온날의 전체 평균 매출액을 바그래프로 출력하세요.
a=pd.DataFrame()
a['날짜별 매출']=order_all.pivot_table(
    index='날짜',
    values='total_amount',
    aggfunc='sum'
)['total_amount']

# %%
a
# Out:
#                날짜별 매출
# 날짜
# 2021-04-01  230492270
# 2021-04-02  230594810
# 2021-04-03  230215180
# 2021-04-04  229802940
# 2021-04-05  230174170
# ...               ...
# 2021-06-26  230824190
# 2021-06-27  230222450
# 2021-06-28  229914420
# 2021-06-29  229876730
# 2021-06-30  230685030
#
# [89 rows x 1 columns]

# %%
a=a.merge(wtall,on='날짜')
a.pivot_table(
    index='날씨',
    values='날짜별 매출',
    aggfunc='mean'
).plot.bar()

# %%
a.pivot_table(
    index='날씨',
    values='날짜별 매출',
    aggfunc='mean'
)
# Out:
#           날짜별 매출
# 날씨
# 맑음  2.302795e+08
# 비   2.301856e+08
